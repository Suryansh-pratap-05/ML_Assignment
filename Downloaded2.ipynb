# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5950d8a08307> in <cell line: 4>()
#       2
#       3 # Load the Iris dataset
# ----> 4 X = iris.data
#       5 y = iris.target
#       6
#
# NameError: name 'iris' is not defined
